# %%
from un_wpp import *
from un_wpp import _load_demographics

# %%
walden_ds = load_walden_ds()
tmp_dir = extract_data(walden_ds)
# df_population, df_fertility, df_demographics, df_depratio, df_deaths = load_data(
#     tmp_dir
# )

# %%
df_demographics[df_demographics.Variant.isna()]
# Out:
#        SortOrder LocID Notes ISO3_code ISO2_code SDMX_code LocTypeID  \
# 44264          1   900   NaN       NaN       NaN         1         1
# 44265          1   900   NaN       NaN       NaN         1         1
# 44266          1   900   NaN       NaN       NaN         1         1
# 44267          1   900   NaN       NaN       NaN         1         1
# 44268          1   900   NaN       NaN       NaN         1         1
# ...          ...   ...   ...       ...       ...       ...       ...
# 292859       290   876     2       WLF        WF       876         4
# 292860       290   876     2       WLF        WF       876         4
# 292861       290   876     2       WLF        WF       876         4
# 292862       290   876     2       WLF        WF       876         4
# 292863       290   876     2       WLF        WF       876         4
#
#          LocTypeName ParentID                   Location  ... Q0060Male  \
# ...

# %%
# Process
df_population, df_fertility, df_demographics, df_depratio, df_deaths = process(
    df_population, df_fertility, df_demographics, df_depratio, df_deaths
)
# Initiate dataset
ds = init_dataset(dest_dir, walden_ds)
# Add tables to dataset
ds = add_tables_to_ds(
    ds, df_population, df_fertility, df_demographics, df_depratio, df_deaths
)

# %%
df = _load_demographics(tmp_dir)

# %%
df[df.Variant.isna()]
# Out:
# Empty DataFrame
# Columns: [SortOrder, LocID, Notes, ISO3_code, ISO2_code, SDMX_code, LocTypeID, LocTypeName, ParentID, Location, VarID, Variant, Time, TPopulation1Jan, TPopulation1July, TPopulationMale1July, TPopulationFemale1July, PopDensity, PopSexRatio, MedianAgePop, NatChange, NatChangeRT, PopChange, PopGrowthRate, DoublingTime, Births, Births1519, CBR, TFR, NNR, MAC, SRB, Deaths, DeathsMale, DeathsFemale, CDR, LEx, LExMale, LExFemale, LE15, LE15Male, LE15Female, LE65, LE65Male, LE65Female, LE80, LE80Male, LE80Female, InfantDeaths, IMR, LBsurvivingAge1, Under5Deaths, Q5, Q0040, Q0040Male, Q0040Female, Q0060, Q0060Male, Q0060Female, Q1550, Q1550Male, Q1550Female, Q1560, Q1560Male, Q1560Female, NetMigrations, CNMR]
# Index: []
#
# [0 rows x 67 columns]

# %%
filenames = [
    f
    for f in filter(lambda x: "Demographic" in x, os.listdir(tmp_dir))
    if "notes" not in f
]

# %%
x = pd.concat(
    [pd.read_csv(os.path.join(tmp_dir, filename)) for filename in filenames],
    ignore_index=True,
)
# Out:
# /tmp/ipykernel_2552772/2527664120.py:3: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(os.path.join(tmp_dir, filename))
# /tmp/ipykernel_2552772/2527664120.py:3: DtypeWarning: Columns (2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(os.path.join(tmp_dir, filename))

# %%
x.Variant.unique()
# Out:
# array(['Medium', 'High', 'Low', 'Constant fertility',
#        'Instant replacement', 'Zero migration', 'Constant mortality',
#        'No change', 'Momentum', 'Instant replacement zero migration'],
#       dtype=object)
